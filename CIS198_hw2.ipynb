# %% [markdown]
# <a href="https://colab.research.google.com/github/anewport-beep/CIS-198-Comp-Ed/blob/main/CIS198_hw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a function in python always has a set of parathesis following the function name. In the parathesis put your function inputs aka ***parameters***.

# %%
print ('hello world')
# Out:
# hello world

# %% [markdown]
# ## Creating a poem with chatgpt
#
# here is our prompt:
#
# here is the output I got:
#
# [Verse 1]
# Intro to Computer Education, roll call, take your seat,
# Purple Eagles soaring while the snow hits the street.
# Sophie clicks, Andrew codes, Hannah’s logic on cue,
# Julien, Joe, Cue—yeah, the whole crew too.
# [Chorus]
# We’re structurin’ programs, step by step,
# Office apps sharp, got the workflow prepped.
# Buildin’ websites while the cold wind blows,
# Purple pride high even when the temp drops low.
# [Verse 2]
# Professor Ty leads with a keyboard grin,
# Admin views of platforms—how the systems all spin.
# Google Slides shining, presentations tight,
# Learning how schools run from morning to night.
# [Bridge]
# No iPhone lessons—nah, that’s not the plan,
# But we code and create like only Eagles can.
# Shoutout my roommate Sean, bundled head to toe,
# Typing through winter like it’s part of the show.
# [Chorus]
# We’re structurin’ programs, step by step,
# Office apps sharp, got the workflow prepped.
# Buildin’ websites while the cold wind blows,
# Purple Eagles flyin’ as the code just flows.
# [Outro]
# From Falls-side frost to the lab’s warm glow,
# Intro to Computer Ed—watch our skills all grow.

# %% [markdown]
# ### Markdown Basics
# -----------
# end a line with two spaces to create a newline***
#
# *italic*
#
# **bold**
#
# Bulleted List:
# * I
# * Like
# * Computers
#
# Numbered List
# 1. Welcome
# 1. to
# 1. Niagara
# 1. University

# %% [markdown]
# ** How to make a Table**
#
# |Name|*Major*|
# |:-------|-------:|
# |Monte|*Computer Science*|
# |Father Maher|Theology|

# %% [markdown]
# #### Links
# [My university](https://niagara.edu)

# %% [markdown]
# %%HTML
#
# <p style="font-size: 100px;">Hello World in Big Font</p>
